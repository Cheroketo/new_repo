# %% [markdown]
# # Исследовательская заготовка: классификация Iris
#
# Notebook демонстрирует минимальный ML-эксперимент: загрузку данных, обучение модели, оценку качества, сохранение артефакта и одно предсказание. Это исходный материал, а не готовый инженерный проект.

# %%
import csv

import joblib
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Подготовка данных и обучение

# %%
iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(
    iris.data,
    iris.target,
    test_size=0.25,
    random_state=42,
    stratify=iris.target,
)

model = LogisticRegression(max_iter=300, random_state=42)
model.fit(X_train, y_train)

# %% [markdown]
# ## Оценка качества

# %%
y_pred = model.predict(X_test)
print(f"accuracy={accuracy_score(y_test, y_pred):.3f}")

# %% [markdown]
# ## Сохранение модели
#
# Путь пока зависит от текущего рабочего каталога. В итоговом проекте это решение нужно сделать явным и надежным.

# %%
joblib.dump(model, "model.pkl")
print("model_saved=model.pkl")

# %% [markdown]
# ## Предсказание для одного объекта
#
# Обучение и инференс пока остаются частями одного notebook. В практической работе их необходимо разделить.

# %%
feature_columns = [
    "sepal_length",
    "sepal_width",
    "petal_length",
    "petal_width",
]

with open("sample.csv", encoding="utf-8", newline="") as sample_file:
    row = next(csv.DictReader(sample_file))

features = [[float(row[column]) for column in feature_columns]]
predicted_class = int(model.predict(features)[0])
predicted_name = iris.target_names[predicted_class]

print(f"predicted_class={predicted_class}")
print(f"predicted_name={predicted_name}")

# %% [markdown]
# ## Следующий шаг
#
# Преобразуйте этот эксперимент в репозиторий с отдельными `src/train.py` и `src/predict.py`, каталогами `models/`, `data_sample/`, `tests/`, воспроизводимыми командами и осмысленной историей Git.
